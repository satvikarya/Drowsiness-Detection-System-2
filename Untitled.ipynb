# %%
import cv2
import os
from keras.models import load_model
import numpy as np
from pygame import mixer
import time
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
mixer.init()
sound = mixer.Sound('alarm.wav')

face = cv2.CascadeClassifier('haar cascade files\haarcascade_frontalface_alt.xml')
leye = cv2.CascadeClassifier('haar cascade files\haarcascade_lefteye_2splits.xml')
reye = cv2.CascadeClassifier('haar cascade files\haarcascade_righteye_2splits.xml')



lbl=['Close','Open']

model = load_model('models/cnncat2.h5')
path = os.getcwd()
cap = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_COMPLEX_SMALL
count=0
score=0
thicc=2
rpred=[99]
lpred=[99]

# %%
while(True):
    ret, frame = cap.read()
    print(frame.shape)

    height,width = frame.shape[:2] 

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    faces = face.detectMultiScale(gray,minNeighbors=5,scaleFactor=1.1,minSize=(25,25))
    left_eye = leye.detectMultiScale(gray)
    right_eye =  reye.detectMultiScale(gray)

    cv2.rectangle(frame, (0,height-50) , (200,height) , (0,0,0) , thickness=cv2.FILLED )
#     print(faces)
    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y) , (x+w,y+h) , (100,100,100) , 1 )

    for (x,y,w,h) in right_eye:
        print("a")
        r_eye=frame[y:y+h,x:x+w]
        count=count+1
        r_eye = cv2.cvtColor(r_eye,cv2.COLOR_BGR2GRAY)
        r_eye = cv2.resize(r_eye,(24,24))
        r_eye= r_eye/255.0
#         print("r_eye",r_eye)
        r_eye=  r_eye.reshape(24,24,-1)
        r_eye = np.expand_dims(r_eye,axis=0)
#         print("r_eye",r_eye)
        rpred = model.predict(r_eye)
#         print(rpred)
#         if(rpred[0][0]>=0.8):
#             lbr='Open' 
#         if(rpred[0][0]==0):
#             lbl='Closed'
        break

    for (x,y,w,h) in left_eye:
        print("b")
        l_eye=frame[y:y+h,x:x+w]
        count=count+1
        l_eye = cv2.cvtColor(l_eye,cv2.COLOR_BGR2GRAY)  
        l_eye = cv2.resize(l_eye,(24,24))
        l_eye= l_eye/255
        l_eye=l_eye.reshape(24,24,-1)
        l_eye = np.expand_dims(l_eye,axis=0)
        lpred = model.predict(l_eye)
#         if(lpred[0][0]==1):
#             lbl='Open'   
#         if(lpred[0][0]==0):
#             lbl='Closed'
        break
    rpred=np.array(rpred)
    lpred=np.array(lpred)
    rpred=rpred.flatten()
    lpred=lpred.flatten()
    print("rpred",rpred)
    print("lpred",lpred)
    if(rpred[0]>=0.8 and lpred[0]>=0.8):
        score=score+1
        cv2.putText(frame,"Closed",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    # if(rpred[0]==1 or lpred[0]==1):
    else:
        score=score-1
        cv2.putText(frame,"Open",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    
        
    if(score<0):
        score=0   
    cv2.putText(frame,'Score:'+str(score),(100,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    if(score>15):
        #person is feeling sleepy so we beep the alarm
        cv2.imwrite(os.path.join(path,'image.jpg'),frame)
        try:
            sound.play()
            
        except:  # isplaying = False
            pass
        if(thicc<16):
            thicc= thicc+2
        else:
            thicc=thicc-2
            if(thicc<2):
                thicc=2
        cv2.rectangle(frame,(0,0),(width,height),(0,0,255),thicc) 
    else:
        sound.stop()
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# cap.release()
# cv2.destroyAllWindows()
# Out:
# (480, 640, 3)
# b
# rpred [99]
# lpred [0.8591959  0.14080408]
# (480, 640, 3)
# a
# b
# rpred [0.9506103  0.04938978]
# lpred [0.92237836 0.07762162]
# (480, 640, 3)
# a
# b
# rpred [0.8030694  0.19693054]
# lpred [0.13397779 0.8660222 ]
# (480, 640, 3)
# a
# b
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# rpred [0.21750826 0.78249174]
# lpred [0.86550796 0.13449207]
# (480, 640, 3)
# b
# rpred [0.21750826 0.78249174]
# lpred [0.986034   0.01396607]
# (480, 640, 3)
# b
# rpred [0.21750826 0.78249174]
# lpred [0.9623147  0.03768524]
# (480, 640, 3)
# b
# rpred [0.21750826 0.78249174]
# lpred [0.5581833 0.4418167]
# (480, 640, 3)
# a
# b
# rpred [0.79550123 0.2044988 ]
# lpred [0.44705045 0.5529496 ]
# (480, 640, 3)
# a
# b
# rpred [0.10443511 0.8955649 ]
# lpred [0.86288816 0.13711184]
# (480, 640, 3)
# b
# rpred [0.10443511 0.8955649 ]
# lpred [0.99738973 0.00261033]
# (480, 640, 3)
# rpred [0.10443511 0.8955649 ]
# lpred [0.99738973 0.00261033]
# (480, 640, 3)
# a
# b
# rpred [0.17782739 0.8221726 ]
# lpred [0.30145267 0.6985473 ]
# (480, 640, 3)
# a
# b
# rpred [0.45900825 0.5409917 ]
# lpred [0.9776225  0.02237754]
# (480, 640, 3)
# a
# b
# rpred [0.9981223  0.00187775]
# lpred [0.00998697 0.990013  ]
# (480, 640, 3)
# a
# b
# rpred [9.9987066e-01 1.2930825e-04]
# lpred [9.9921966e-01 7.8038726e-04]
# (480, 640, 3)
# a
# rpred [0.9717157 0.0282843]
# lpred [9.9921966e-01 7.8038726e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9997950e-01 2.0525868e-05]
# lpred [0.96501034 0.03498964]
# (480, 640, 3)
# a
# b
# rpred [0.9894895  0.01051048]
# lpred [0.998071   0.00192897]
# (480, 640, 3)
# a
# rpred [0.990906   0.00909402]
# lpred [0.998071   0.00192897]
# (480, 640, 3)
# a
# b
# rpred [0.0310923 0.9689077]
# lpred [0.9589391 0.0410609]
# (480, 640, 3)
# a
# b
# rpred [0.10426097 0.8957391 ]
# lpred [0.20581912 0.79418087]
# (480, 640, 3)
# a
# b
# rpred [0.04151025 0.9584897 ]
# lpred [0.8069352  0.19306481]
# (480, 640, 3)
# a
# b
# rpred [0.211148 0.788852]
# lpred [0.06181701 0.93818307]
# (480, 640, 3)
# a
# b
# rpred [9.9994576e-01 5.4254328e-05]
# lpred [9.9996185e-01 3.8151684e-05]
# (480, 640, 3)
# a
# b
# rpred [0.5750509  0.42494908]
# lpred [0.7055867 0.2944133]
# (480, 640, 3)
# a
# b
# rpred [0.16148745 0.83851254]
# lpred [0.11890817 0.8810918 ]
# (480, 640, 3)
# a
# b
# rpred [0.27392608 0.7260739 ]
# lpred [0.41819787 0.5818021 ]
# (480, 640, 3)
# a
# b
# rpred [9.9991715e-01 8.2866231e-05]
# lpred [0.28257322 0.7174268 ]
# (480, 640, 3)
# a
# b
# rpred [0.02332992 0.97667015]
# lpred [0.06802146 0.9319785 ]
# (480, 640, 3)
# a
# b
# rpred [0.18994997 0.81005   ]
# lpred [0.06644515 0.9335548 ]
# (480, 640, 3)
# a
# b
# rpred [0.03670472 0.9632952 ]
# lpred [0.3636447 0.6363552]
# (480, 640, 3)
# a
# b
# rpred [0.99288017 0.00711987]
# lpred [0.9966001  0.00339992]
# (480, 640, 3)
# a
# b
# rpred [0.7343098 0.2656902]
# lpred [0.8301614  0.16983867]
# (480, 640, 3)
# a
# b
# rpred [0.16003537 0.83996457]
# lpred [0.4897425 0.5102576]
# (480, 640, 3)
# a
# b
# rpred [0.17801102 0.821989  ]
# lpred [0.1534573  0.84654266]
# (480, 640, 3)
# a
# b
# rpred [0.03598048 0.96401954]
# lpred [0.7850887  0.21491124]
# (480, 640, 3)
# a
# b
# rpred [0.1584439  0.84155613]
# lpred [0.6076993  0.39230075]
# (480, 640, 3)
# a
# b
# rpred [0.03205801 0.96794194]
# lpred [0.01426581 0.9857342 ]
# (480, 640, 3)
# a
# b
# rpred [0.00962805 0.99037194]
# lpred [0.14785764 0.8521424 ]
# (480, 640, 3)
# a
# b
# rpred [0.01265513 0.9873448 ]
# lpred [0.01864022 0.9813597 ]
# (480, 640, 3)
# a
# b
# rpred [0.07023823 0.92976177]
# lpred [0.9729551  0.02704487]
# (480, 640, 3)
# a
# b
# rpred [0.0507905 0.9492096]
# lpred [0.65803176 0.34196824]
# (480, 640, 3)
# a
# b
# rpred [0.02218956 0.9778104 ]
# lpred [0.95810336 0.04189657]
# (480, 640, 3)
# a
# b
# rpred [0.05438336 0.94561666]
# lpred [0.1895601 0.8104399]
# (480, 640, 3)
# a
# b
# rpred [0.00752721 0.99247277]
# lpred [0.05360927 0.94639075]
# (480, 640, 3)
# a
# b
# rpred [0.0023105 0.9976895]
# lpred [0.01280697 0.98719305]
# (480, 640, 3)
# a
# b
# rpred [0.01823044 0.9817695 ]
# lpred [0.00468909 0.99531096]
# (480, 640, 3)
# a
# b
# rpred [0.05561215 0.94438785]
# lpred [0.33076674 0.66923326]
# (480, 640, 3)
# a
# b
# rpred [0.0102785 0.9897215]
# lpred [0.08182625 0.91817373]
# (480, 640, 3)
# a
# b
# rpred [0.06456942 0.9354305 ]
# lpred [0.9974873  0.00251274]
# (480, 640, 3)
# a
# b
# rpred [0.01465712 0.98534286]
# lpred [0.03127014 0.9687299 ]
# (480, 640, 3)
# a
# b
# rpred [0.08384602 0.91615397]
# lpred [0.20191926 0.7980808 ]
# (480, 640, 3)
# a
# b
# rpred [0.09874379 0.9012562 ]
# lpred [0.06006237 0.93993765]
# (480, 640, 3)
# b
# rpred [0.09874379 0.9012562 ]
# lpred [0.9958883  0.00411176]
# (480, 640, 3)
# b
# rpred [0.09874379 0.9012562 ]
# lpred [0.0684472 0.9315528]
# (480, 640, 3)
# b
# rpred [0.09874379 0.9012562 ]
# lpred [0.11107627 0.88892376]
# (480, 640, 3)
# rpred [0.09874379 0.9012562 ]
# lpred [0.11107627 0.88892376]
# (480, 640, 3)
# rpred [0.09874379 0.9012562 ]
# lpred [0.11107627 0.88892376]
# (480, 640, 3)
# rpred [0.09874379 0.9012562 ]
# lpred [0.11107627 0.88892376]
# (480, 640, 3)
# rpred [0.09874379 0.9012562 ]
# lpred [0.11107627 0.88892376]
# (480, 640, 3)
# rpred [0.09874379 0.9012562 ]
# lpred [0.11107627 0.88892376]
# (480, 640, 3)
# b
# rpred [0.09874379 0.9012562 ]
# lpred [0.49970812 0.50029194]
# (480, 640, 3)
# b
# rpred [0.09874379 0.9012562 ]
# lpred [0.8510238  0.14897622]
# (480, 640, 3)
# a
# b
# rpred [0.9961056  0.00389438]
# lpred [0.9836189  0.01638108]
# (480, 640, 3)
# b
# rpred [0.9961056  0.00389438]
# lpred [0.0358215  0.96417844]
# (480, 640, 3)
# a
# b
# rpred [0.9318345 0.0681655]
# lpred [0.9944522  0.00554775]
# (480, 640, 3)
# a
# b
# rpred [0.9612204  0.03877954]
# lpred [0.99161524 0.00838469]
# (480, 640, 3)
# a
# b
# rpred [0.9104568  0.08954328]
# lpred [0.68338394 0.31661606]
# (480, 640, 3)
# a
# b
# rpred [0.05576633 0.9442337 ]
# lpred [0.8147399  0.18526012]
# (480, 640, 3)
# a
# b
# rpred [0.01343776 0.9865623 ]
# lpred [0.27437693 0.72562313]
# (480, 640, 3)
# a
# b
# rpred [0.0183576  0.98164237]
# lpred [0.29462656 0.7053734 ]
# (480, 640, 3)
# a
# b
# rpred [0.01522871 0.9847713 ]
# lpred [0.74891543 0.2510845 ]
# (480, 640, 3)
# a
# b
# rpred [9.9998701e-01 1.2962821e-05]
# lpred [9.999844e-01 1.560978e-05]
# (480, 640, 3)
# a
# b
# rpred [0.02016692 0.9798331 ]
# lpred [0.16689199 0.833108  ]
# (480, 640, 3)
# a
# b
# rpred [0.05636416 0.9436358 ]
# lpred [0.7770881 0.2229119]
# (480, 640, 3)
# a
# b
# rpred [0.01444751 0.9855525 ]
# lpred [0.41560704 0.58439296]
# (480, 640, 3)
# a
# b
# rpred [0.04529048 0.95470953]
# lpred [0.02089036 0.97910964]
# (480, 640, 3)
# a
# b
# rpred [0.06496647 0.9350335 ]
# lpred [0.6895109  0.31048915]
# (480, 640, 3)
# a
# b
# rpred [0.48548618 0.51451385]
# lpred [0.73976684 0.26023322]
# (480, 640, 3)
# a
# b
# rpred [0.49262705 0.507373  ]
# lpred [0.8640221  0.13597797]
# (480, 640, 3)
# a
# b
# rpred [0.05758863 0.94241136]
# lpred [0.29185003 0.7081499 ]
# (480, 640, 3)
# a
# b
# rpred [0.10823888 0.8917611 ]
# lpred [0.60055614 0.39944384]
# (480, 640, 3)
# a
# b
# rpred [0.09036832 0.90963167]
# lpred [0.57624197 0.42375803]
# (480, 640, 3)
# a
# b
# rpred [0.20293337 0.7970666 ]
# lpred [0.9007344  0.09926559]
# (480, 640, 3)
# a
# b
# rpred [0.09104583 0.90895414]
# lpred [0.829307   0.17069301]
# (480, 640, 3)
# a
# b
# rpred [0.02883772 0.97116226]
# lpred [0.4009732 0.5990268]
# (480, 640, 3)
# a
# b
# rpred [0.08379422 0.9162058 ]
# lpred [0.30636537 0.6936346 ]
# (480, 640, 3)
# a
# b
# rpred [0.03644779 0.9635522 ]
# lpred [0.14706132 0.8529387 ]
# (480, 640, 3)
# a
# b
# rpred [0.05613502 0.943865  ]
# lpred [0.32551983 0.67448014]
# (480, 640, 3)
# a
# b
# rpred [0.17269154 0.8273084 ]
# lpred [0.3519831  0.64801687]
# (480, 640, 3)
# a
# b
# rpred [0.67821634 0.32178375]
# lpred [0.07224283 0.9277572 ]
# (480, 640, 3)
# a
# b
# rpred [0.53957814 0.46042186]
# lpred [0.2763758 0.7236242]
# (480, 640, 3)
# a
# b
# rpred [0.01688928 0.9831108 ]
# lpred [0.17522445 0.8247755 ]
# (480, 640, 3)
# a
# b
# rpred [0.02781305 0.9721869 ]
# lpred [0.00164187 0.9983581 ]
# (480, 640, 3)
# a
# b
# rpred [0.01853297 0.98146695]
# lpred [0.01006814 0.9899318 ]
# (480, 640, 3)
# a
# b
# rpred [0.0192004  0.98079956]
# lpred [0.26262394 0.7373761 ]
# (480, 640, 3)
# a
# b
# rpred [0.06045038 0.9395496 ]
# lpred [0.11105426 0.88894576]
# (480, 640, 3)
# a
# b
# rpred [0.00765123 0.9923488 ]
# lpred [0.2284025 0.7715975]
# (480, 640, 3)
# a
# b
# rpred [0.02700764 0.97299236]
# lpred [0.284396 0.715604]
# (480, 640, 3)
# a
# b
# rpred [0.03368262 0.9663174 ]
# lpred [0.12105177 0.8789482 ]
# (480, 640, 3)
# a
# b
# rpred [0.02315176 0.97684824]
# lpred [0.09053177 0.9094682 ]
# (480, 640, 3)
# a
# b
# rpred [0.221501 0.778499]
# lpred [0.58545005 0.41454995]
# (480, 640, 3)
# a
# b
# rpred [0.26175082 0.7382492 ]
# lpred [0.5483365  0.45166343]
# (480, 640, 3)
# a
# b
# rpred [0.03329349 0.96670645]
# lpred [0.4423621 0.5576379]
# (480, 640, 3)
# a
# b
# rpred [0.1284765 0.8715235]
# lpred [0.31813487 0.68186516]
# (480, 640, 3)
# a
# b
# rpred [0.1234598 0.8765402]
# lpred [0.6738558  0.32614425]
# (480, 640, 3)
# a
# b
# rpred [0.07493571 0.9250643 ]
# lpred [0.15263869 0.84736127]
# (480, 640, 3)
# a
# b
# rpred [0.01476911 0.9852309 ]
# lpred [0.38343546 0.6165646 ]
# (480, 640, 3)
# a
# b
# rpred [0.5807143  0.41928574]
# lpred [0.71681017 0.28318983]
# (480, 640, 3)
# a
# b
# rpred [0.87353635 0.12646365]
# lpred [0.80747145 0.19252853]
# (480, 640, 3)
# a
# b
# rpred [0.07888292 0.9211171 ]
# lpred [7.1362592e-04 9.9928635e-01]
# (480, 640, 3)
# a
# rpred [0.917439   0.08256102]
# lpred [7.1362592e-04 9.9928635e-01]
# (480, 640, 3)
# a
# b
# rpred [0.06769036 0.9323096 ]
# lpred [0.5421368  0.45786327]
# (480, 640, 3)
# a
# b
# rpred [0.10155629 0.8984437 ]
# lpred [0.75717473 0.24282522]
# (480, 640, 3)
# a
# b
# rpred [0.02879462 0.9712054 ]
# lpred [0.3344057 0.6655943]
# (480, 640, 3)
# a
# b
# rpred [0.08169655 0.91830343]
# lpred [0.60591847 0.39408156]
# (480, 640, 3)
# a
# b
# rpred [0.3119327  0.68806726]
# lpred [0.9342552  0.06574479]
# (480, 640, 3)
# a
# b
# rpred [0.6782097  0.32179022]
# lpred [0.97460765 0.02539237]
# (480, 640, 3)
# a
# rpred [0.5508907  0.44910932]
# lpred [0.97460765 0.02539237]
# (480, 640, 3)
# a
# b
# rpred [0.16236462 0.83763534]
# lpred [0.18423383 0.81576616]
# (480, 640, 3)
# a
# b
# rpred [0.49765757 0.5023424 ]
# lpred [0.0694899 0.9305101]
# (480, 640, 3)
# a
# b
# rpred [0.75984925 0.24015081]
# lpred [0.10144955 0.89855045]
# (480, 640, 3)
# a
# b
# rpred [0.00289787 0.9971021 ]
# lpred [5.789473e-04 9.994211e-01]
# (480, 640, 3)
# a
# b
# rpred [8.394283e-04 9.991605e-01]
# lpred [2.1567264e-04 9.9978429e-01]
# (480, 640, 3)
# a
# rpred [0.9978775  0.00212259]
# lpred [2.1567264e-04 9.9978429e-01]
# (480, 640, 3)
# a
# rpred [0.98204535 0.01795468]
# lpred [2.1567264e-04 9.9978429e-01]
# (480, 640, 3)
# a
# b
# rpred [0.27295202 0.72704804]
# lpred [0.2220359 0.7779641]
# (480, 640, 3)
# a
# b
# rpred [0.16772379 0.8322762 ]
# lpred [0.12694281 0.8730571 ]
# (480, 640, 3)
# a
# b
# rpred [0.21555683 0.7844432 ]
# lpred [0.7786446  0.22135541]
# (480, 640, 3)
# a
# b
# rpred [0.00864044 0.99135953]
# lpred [0.3994839 0.6005161]
# (480, 640, 3)
# a
# b
# rpred [0.04309038 0.95690954]
# lpred [0.42609096 0.57390904]
# (480, 640, 3)
# a
# b
# rpred [0.05531334 0.94468665]
# lpred [0.43952063 0.56047934]
# (480, 640, 3)
# a
# b
# rpred [0.01363649 0.9863635 ]
# lpred [0.07698879 0.9230112 ]
# (480, 640, 3)
# a
# b
# rpred [0.00751181 0.99248815]
# lpred [0.09200423 0.90799576]
# (480, 640, 3)
# a
# b
# rpred [9.996661e-01 3.339454e-04]
# lpred [0.96770847 0.03229153]
# (480, 640, 3)
# a
# b
# rpred [0.08416946 0.9158305 ]
# lpred [0.27025992 0.72974014]
# (480, 640, 3)
# a
# b
# rpred [0.01547984 0.98452014]
# lpred [0.15585299 0.844147  ]
# (480, 640, 3)
# a
# b
# rpred [0.00791398 0.992086  ]
# lpred [0.39727882 0.6027213 ]
# (480, 640, 3)
# a
# b
# rpred [0.00308356 0.9969164 ]
# lpred [0.04327869 0.9567213 ]
# (480, 640, 3)
# a
# b
# rpred [9.9998629e-01 1.3717898e-05]
# lpred [9.9991691e-01 8.3132414e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999249e-01 7.5331177e-06]
# lpred [9.9998522e-01 1.4729483e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999619e-01 3.8043538e-06]
# lpred [9.9998677e-01 1.3212059e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9995565e-01 4.4320528e-05]
# lpred [9.9999213e-01 7.8756111e-06]
# (480, 640, 3)
# a
# b
# rpred [9.9999666e-01 3.3852518e-06]
# lpred [9.999387e-01 6.128788e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999297e-01 6.9971215e-06]
# lpred [9.9999785e-01 2.1546623e-06]
# (480, 640, 3)
# a
# b
# rpred [9.9999821e-01 1.7646915e-06]
# lpred [9.9991035e-01 8.9646244e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999881e-01 1.1621569e-06]
# lpred [9.9988139e-01 1.1855881e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9999809e-01 1.9129602e-06]
# lpred [9.9987853e-01 1.2142951e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9999905e-01 9.2682996e-07]
# lpred [9.9995697e-01 4.3002521e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999666e-01 3.3465976e-06]
# lpred [9.9999034e-01 9.6457225e-06]
# (480, 640, 3)
# a
# b
# rpred [9.9999332e-01 6.6703637e-06]
# lpred [9.999629e-01 3.709469e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999213e-01 7.8369512e-06]
# lpred [9.9997997e-01 2.0069756e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9959594e-01 4.0408841e-04]
# lpred [9.9994695e-01 5.3007399e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9994612e-01 5.3858017e-05]
# lpred [9.9957103e-01 4.2895364e-04]
# (480, 640, 3)
# a
# b
# rpred [0.7969155  0.20308453]
# lpred [0.6606949  0.33930513]
# (480, 640, 3)
# a
# b
# rpred [0.29620907 0.70379096]
# lpred [0.94619787 0.05380214]
# (480, 640, 3)
# a
# b
# rpred [0.00905316 0.9909469 ]
# lpred [0.81961524 0.18038474]
# (480, 640, 3)
# a
# b
# rpred [0.04987251 0.9501275 ]
# lpred [0.6399851  0.36001495]
# (480, 640, 3)
# a
# b
# rpred [0.11413446 0.8858655 ]
# lpred [0.75062215 0.24937786]
# (480, 640, 3)
# a
# b
# rpred [0.3328521  0.66714793]
# lpred [0.84728324 0.1527168 ]
# (480, 640, 3)
# a
# b
# rpred [0.03592316 0.9640768 ]
# lpred [0.36198655 0.6380135 ]
# (480, 640, 3)
# a
# b
# rpred [0.01868668 0.98131335]
# lpred [0.71241736 0.28758267]
# (480, 640, 3)
# a
# b
# rpred [0.04137185 0.9586282 ]
# lpred [0.7589341  0.24106587]
# (480, 640, 3)
# a
# b
# rpred [0.03796911 0.9620309 ]
# lpred [0.9662899  0.03371013]
# (480, 640, 3)
# a
# b
# rpred [0.07676791 0.92323214]
# lpred [0.89150167 0.1084983 ]
# (480, 640, 3)
# a
# b
# rpred [0.08166917 0.91833085]
# lpred [0.3748167  0.62518334]
# (480, 640, 3)
# a
# b
# rpred [0.2547656 0.7452345]
# lpred [0.5242534 0.4757466]
# (480, 640, 3)
# a
# b
# rpred [0.01277804 0.987222  ]
# lpred [0.8050039  0.19499615]
# (480, 640, 3)
# a
# b
# rpred [0.1875699 0.8124301]
# lpred [0.45207193 0.54792804]
# (480, 640, 3)
# a
# b
# rpred [0.9962528  0.00374726]
# lpred [9.9998009e-01 1.9956007e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9992645e-01 7.3600677e-05]
# lpred [9.9979550e-01 2.0457186e-04]
# (480, 640, 3)
# a
# b
# rpred [9.999918e-01 8.274641e-06]
# lpred [9.999325e-01 6.741985e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999094e-01 9.0207550e-06]
# lpred [9.9947137e-01 5.2863354e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9993336e-01 6.6634122e-05]
# lpred [9.9984324e-01 1.5677862e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9995732e-01 4.2711206e-05]
# lpred [9.9997580e-01 2.4235882e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9998784e-01 1.2176164e-05]
# lpred [9.9998116e-01 1.8815481e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999554e-01 4.463470e-05]
# lpred [9.9956447e-01 4.3548894e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9998426e-01 1.5782110e-05]
# lpred [9.9990916e-01 9.0832880e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9996006e-01 3.9973474e-05]
# lpred [9.9984753e-01 1.5242770e-04]
# (480, 640, 3)
# a
# b
# rpred [0.99745136 0.00254864]
# lpred [0.9989768 0.0010232]
# (480, 640, 3)
# a
# b
# rpred [0.01733124 0.98266876]
# lpred [0.40732834 0.59267175]
# (480, 640, 3)
# a
# b
# rpred [0.0289478  0.97105217]
# lpred [0.12584761 0.8741524 ]
# (480, 640, 3)
# a
# b
# rpred [0.06285779 0.9371422 ]
# lpred [0.8332655  0.16673453]
# (480, 640, 3)
# a
# b
# rpred [0.05465417 0.9453459 ]
# lpred [0.68896806 0.31103188]
# (480, 640, 3)
# a
# b
# rpred [0.11491424 0.8850857 ]
# lpred [0.16246653 0.8375335 ]
# (480, 640, 3)
# a
# b
# rpred [0.0264026 0.9735974]
# lpred [0.87697905 0.1230209 ]
# (480, 640, 3)
# a
# b
# rpred [0.06429856 0.93570143]
# lpred [0.5953879  0.40461212]
# (480, 640, 3)
# a
# b
# rpred [0.00899485 0.9910052 ]
# lpred [0.96351343 0.03648652]
# (480, 640, 3)
# a
# b
# rpred [0.35303253 0.6469675 ]
# lpred [0.76343167 0.23656833]
# (480, 640, 3)
# a
# b
# rpred [0.05637322 0.94362676]
# lpred [0.758136 0.241864]
# (480, 640, 3)
# a
# b
# rpred [0.0143996 0.9856005]
# lpred [0.63421595 0.3657841 ]
# (480, 640, 3)
# a
# b
# rpred [0.01210496 0.987895  ]
# lpred [0.6949658  0.30503425]
# (480, 640, 3)
# a
# b
# rpred [0.01670826 0.9832917 ]
# lpred [0.18104482 0.8189552 ]
# (480, 640, 3)
# a
# b
# rpred [0.04035966 0.9596404 ]
# lpred [0.46111017 0.5388899 ]
# (480, 640, 3)
# a
# b
# rpred [0.03339136 0.96660864]
# lpred [0.28753328 0.7124667 ]
# (480, 640, 3)
# a
# b
# rpred [0.00942102 0.99057895]
# lpred [0.21503347 0.78496647]
# (480, 640, 3)
# a
# b
# rpred [0.01266084 0.98733914]
# lpred [0.10252706 0.897473  ]
# (480, 640, 3)
# a
# b
# rpred [0.01601145 0.9839886 ]
# lpred [0.17100263 0.8289974 ]
# (480, 640, 3)
# a
# b
# rpred [0.00451575 0.99548423]
# lpred [0.31620428 0.68379575]
# (480, 640, 3)
# a
# b
# rpred [0.02849124 0.97150874]
# lpred [0.04626258 0.95373744]
# (480, 640, 3)
# a
# b
# rpred [0.00422715 0.9957729 ]
# lpred [0.31625044 0.68374956]
# (480, 640, 3)
# a
# b
# rpred [0.00995446 0.9900455 ]
# lpred [0.32990107 0.67009896]
# (480, 640, 3)
# a
# b
# rpred [0.01054412 0.9894559 ]
# lpred [0.1488192 0.8511808]
# (480, 640, 3)
# a
# b
# rpred [0.07698674 0.9230133 ]
# lpred [0.30834293 0.69165707]
# (480, 640, 3)
# a
# b
# rpred [0.033344 0.966656]
# lpred [0.3202628 0.6797372]
# (480, 640, 3)
# a
# b
# rpred [0.05364034 0.9463597 ]
# lpred [0.52731806 0.472682  ]
# (480, 640, 3)
# a
# b
# rpred [0.03707771 0.9629223 ]
# lpred [0.76426    0.23573999]
# (480, 640, 3)
# a
# b
# rpred [0.05992736 0.9400726 ]
# lpred [0.72604305 0.27395692]
# (480, 640, 3)
# a
# b
# rpred [0.7357731  0.26422688]
# lpred [0.48068237 0.5193177 ]
# (480, 640, 3)
# a
# b
# rpred [0.09070799 0.90929204]
# lpred [0.05581286 0.94418716]
# (480, 640, 3)
# a
# b
# rpred [0.2050114 0.7949886]
# lpred [0.65136147 0.3486385 ]
# (480, 640, 3)
# a
# b
# rpred [0.05562207 0.94437796]
# lpred [0.30715415 0.6928459 ]
# (480, 640, 3)
# a
# b
# rpred [0.10879779 0.89120215]
# lpred [0.7169859  0.28301412]
# (480, 640, 3)
# a
# b
# rpred [0.10667965 0.8933204 ]
# lpred [0.6569712 0.3430288]
# (480, 640, 3)
# a
# b
# rpred [0.04777265 0.95222735]
# lpred [0.39082995 0.6091701 ]
# (480, 640, 3)
# a
# b
# rpred [9.9975020e-01 2.4985019e-04]
# lpred [9.999689e-01 3.116486e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999344e-01 6.5715794e-06]
# lpred [9.9985170e-01 1.4825759e-04]
# (480, 640, 3)
# a
# b
# rpred [9.999778e-01 2.221841e-05]
# lpred [9.9991536e-01 8.4687723e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997115e-01 2.8844242e-05]
# lpred [9.9998462e-01 1.5419613e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999968e-01 3.213534e-06]
# lpred [9.9991536e-01 8.4591666e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9996686e-01 3.3189659e-05]
# lpred [9.9998558e-01 1.4445957e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999633e-01 3.677354e-05]
# lpred [9.999120e-01 8.798629e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9998498e-01 1.4993129e-05]
# lpred [9.9994707e-01 5.2902156e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999933e-01 6.680575e-06]
# lpred [9.9997675e-01 2.3200946e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999536e-01 4.641788e-05]
# lpred [9.9996221e-01 3.7740567e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999368e-01 6.3760313e-06]
# lpred [9.999902e-01 9.765100e-06]
# (480, 640, 3)
# a
# b
# rpred [9.9997556e-01 2.4413197e-05]
# lpred [9.9991977e-01 8.0248625e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997258e-01 2.7428605e-05]
# lpred [9.9982750e-01 1.7244637e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9998164e-01 1.8323801e-05]
# lpred [9.999273e-01 7.268820e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997914e-01 2.0803671e-05]
# lpred [9.9994957e-01 5.0364506e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999833e-01 1.6590825e-06]
# lpred [9.9996316e-01 3.6830887e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999666e-01 3.3593242e-06]
# lpred [9.9995196e-01 4.7993864e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9996555e-01 3.4502227e-05]
# lpred [9.999267e-01 7.326728e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999523e-01 4.7602430e-06]
# lpred [9.999229e-01 7.710904e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997735e-01 2.2656834e-05]
# lpred [9.9978727e-01 2.1274084e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9996853e-01 3.1512907e-05]
# lpred [9.998499e-01 1.500968e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9997640e-01 2.3651994e-05]
# lpred [9.999677e-01 3.232437e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9998653e-01 1.3481688e-05]
# lpred [9.9999523e-01 4.7146659e-06]
# (480, 640, 3)
# a
# b
# rpred [9.999790e-01 2.103158e-05]
# lpred [9.999666e-01 3.335462e-05]
# (480, 640, 3)
# a
# b
# rpred [9.998350e-01 1.649556e-04]
# lpred [9.9996638e-01 3.3571683e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9967337e-01 3.2661756e-04]
# lpred [9.9994576e-01 5.4271357e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999177e-01 8.1972685e-06]
# lpred [9.998697e-01 1.302865e-04]
# (480, 640, 3)
# a
# b
# rpred [9.999646e-01 3.539336e-05]
# lpred [9.999652e-01 3.481795e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9966967e-01 3.3034477e-04]
# lpred [9.9995291e-01 4.7115922e-05]
# (480, 640, 3)
# a
# rpred [9.9998236e-01 1.7591112e-05]
# lpred [9.9995291e-01 4.7115922e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999285e-01 7.1681438e-06]
# lpred [9.994717e-01 5.283248e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9997187e-01 2.8152450e-05]
# lpred [9.9995255e-01 4.7456739e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997592e-01 2.4087445e-05]
# lpred [9.9980778e-01 1.9229992e-04]
# (480, 640, 3)
# a
# b
# rpred [0.9785277  0.02147223]
# lpred [9.997484e-01 2.516408e-04]
# (480, 640, 3)
# a
# b
# rpred [0.2521396 0.7478604]
# lpred [0.3065356 0.6934644]
# (480, 640, 3)
# a
# b
# rpred [0.16647258 0.8335274 ]
# lpred [0.24440451 0.75559545]
# (480, 640, 3)
# a
# b
# rpred [0.01726848 0.9827315 ]
# lpred [0.47806743 0.52193254]
# (480, 640, 3)
# a
# b
# rpred [0.06683262 0.93316734]
# lpred [0.51353943 0.4864605 ]
# (480, 640, 3)
# a
# b
# rpred [0.0048734 0.9951266]
# lpred [0.13260767 0.8673923 ]
# (480, 640, 3)
# a
# b
# rpred [0.09928311 0.9007169 ]
# lpred [0.09333807 0.90666187]
# (480, 640, 3)
# a
# b
# rpred [0.01264921 0.98735076]
# lpred [0.22021055 0.7797894 ]
# (480, 640, 3)
# a
# b
# rpred [0.03437516 0.96562487]
# lpred [0.4737982 0.5262018]
# (480, 640, 3)
# a
# b
# rpred [0.06124895 0.93875104]
# lpred [0.47368124 0.5263188 ]
# (480, 640, 3)
# a
# b
# rpred [0.03371828 0.96628165]
# lpred [0.7997042  0.20029587]
# (480, 640, 3)
# a
# b
# rpred [0.12816001 0.87184   ]
# lpred [0.26395482 0.73604524]
# (480, 640, 3)
# a
# b
# rpred [0.6361785  0.36382142]
# lpred [0.99549603 0.00450393]
# (480, 640, 3)
# a
# b
# rpred [0.929943   0.07005695]
# lpred [9.994324e-01 5.676384e-04]
# (480, 640, 3)
# a
# b
# rpred [0.2168557 0.7831443]
# lpred [0.09211434 0.9078856 ]
# (480, 640, 3)
# a
# b
# rpred [0.09671126 0.9032888 ]
# lpred [0.56593657 0.43406343]
# (480, 640, 3)
# a
# b
# rpred [0.08452433 0.91547567]
# lpred [0.7796328  0.22036722]
# (480, 640, 3)
# a
# b
# rpred [0.20682392 0.79317605]
# lpred [0.04037875 0.95962125]
# (480, 640, 3)
# a
# b
# rpred [0.2986594 0.7013406]
# lpred [0.49612716 0.50387275]
# (480, 640, 3)
# a
# rpred [0.00672161 0.9932783 ]
# lpred [0.49612716 0.50387275]
# (480, 640, 3)
# a
# rpred [0.9769718  0.02302816]
# lpred [0.49612716 0.50387275]
# (480, 640, 3)
# a
# b
# rpred [0.61032355 0.38967645]
# lpred [9.9998498e-01 1.5042627e-05]
# (480, 640, 3)
# a
# b
# rpred [0.04602667 0.95397335]
# lpred [3.2189996e-06 9.9999678e-01]
# (480, 640, 3)
# b
# rpred [0.04602667 0.95397335]
# lpred [0.21832499 0.78167504]
# (480, 640, 3)
# b
# rpred [0.04602667 0.95397335]
# lpred [0.07274758 0.9272524 ]
# (480, 640, 3)
# b
# rpred [0.04602667 0.95397335]
# lpred [0.42143092 0.57856905]
# (480, 640, 3)
# b
# rpred [0.04602667 0.95397335]
# lpred [0.30902427 0.69097567]
# (480, 640, 3)
# b
# rpred [0.04602667 0.95397335]
# lpred [0.03941366 0.9605863 ]
# (480, 640, 3)
# rpred [0.04602667 0.95397335]
# lpred [0.03941366 0.9605863 ]
# (480, 640, 3)
# rpred [0.04602667 0.95397335]
# lpred [0.03941366 0.9605863 ]
# (480, 640, 3)
# rpred [0.04602667 0.95397335]
# lpred [0.03941366 0.9605863 ]
# (480, 640, 3)
# rpred [0.04602667 0.95397335]
# lpred [0.03941366 0.9605863 ]
# (480, 640, 3)
# rpred [0.04602667 0.95397335]
# lpred [0.03941366 0.9605863 ]
# (480, 640, 3)
# rpred [0.04602667 0.95397335]
# lpred [0.03941366 0.9605863 ]
# (480, 640, 3)
# a
# b
# rpred [0.9794707  0.02052938]
# lpred [0.8056389  0.19436112]
# (480, 640, 3)
# a
# b
# rpred [0.09135848 0.90864146]
# lpred [0.8529095  0.14709046]
# (480, 640, 3)
# a
# b
# rpred [0.6548439  0.34515616]
# lpred [9.9997771e-01 2.2267577e-05]
# (480, 640, 3)
# a
# b
# rpred [0.97968787 0.02031208]
# lpred [0.99832255 0.00167747]
# (480, 640, 3)
# a
# b
# rpred [9.9977595e-01 2.2408433e-04]
# lpred [9.9989736e-01 1.0264871e-04]
# (480, 640, 3)
# a
# rpred [9.9999833e-01 1.6860001e-06]
# lpred [9.9989736e-01 1.0264871e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9970251e-01 2.9748047e-04]
# lpred [9.9985361e-01 1.4636245e-04]
# (480, 640, 3)
# a
# b
# rpred [0.9985915  0.00140849]
# lpred [9.996112e-01 3.888349e-04]
# (480, 640, 3)
# a
# b
# rpred [0.997393   0.00260695]
# lpred [0.97513264 0.02486737]
# (480, 640, 3)
# a
# b
# rpred [0.23079294 0.769207  ]
# lpred [0.25457194 0.7454281 ]
# (480, 640, 3)
# a
# b
# rpred [0.11205555 0.8879444 ]
# lpred [0.8532173 0.1467827]
# (480, 640, 3)
# a
# b
# rpred [0.08710053 0.9128995 ]
# lpred [0.5059109  0.49408916]
# (480, 640, 3)
# a
# b
# rpred [9.9978298e-01 2.1703188e-04]
# lpred [9.9989295e-01 1.0707803e-04]
# (480, 640, 3)
# a
# b
# rpred [0.00616686 0.9938332 ]
# lpred [0.02307876 0.97692126]
# (480, 640, 3)
# a
# b
# rpred [0.41550073 0.5844993 ]
# lpred [0.07647227 0.9235277 ]
# (480, 640, 3)
# a
# b
# rpred [0.48102552 0.5189744 ]
# lpred [0.9680214  0.03197866]
# (480, 640, 3)
# a
# b
# rpred [0.8476423  0.15235774]
# lpred [0.4330432 0.5669568]
# (480, 640, 3)
# a
# rpred [9.9968052e-01 3.1948797e-04]
# lpred [0.4330432 0.5669568]
# (480, 640, 3)
# a
# b
# rpred [0.9453483  0.05465167]
# lpred [0.9875936  0.01240648]
# (480, 640, 3)
# a
# b
# rpred [0.18038106 0.81961894]
# lpred [0.27114567 0.7288543 ]
# (480, 640, 3)
# a
# b
# rpred [0.33401787 0.6659821 ]
# lpred [0.071572 0.928428]
# (480, 640, 3)
# a
# b
# rpred [0.12843367 0.87156636]
# lpred [0.68033576 0.31966427]
# (480, 640, 3)
# a
# b
# rpred [0.06330355 0.9366964 ]
# lpred [0.95312387 0.04687618]
# (480, 640, 3)
# a
# b
# rpred [0.41309062 0.5869094 ]
# lpred [0.96811134 0.03188873]
# (480, 640, 3)
# a
# b
# rpred [9.999715e-01 2.852953e-05]
# lpred [9.9997199e-01 2.7974636e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999783e-01 2.164672e-05]
# lpred [9.9997473e-01 2.5224841e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999956e-01 4.446084e-06]
# lpred [9.999889e-01 1.103827e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999404e-01 5.9332688e-06]
# lpred [9.9993968e-01 6.0314684e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9998367e-01 1.6273532e-05]
# lpred [9.9993813e-01 6.1846331e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999344e-01 6.5874110e-06]
# lpred [9.9992335e-01 7.6604359e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999428e-01 5.718710e-05]
# lpred [9.9996936e-01 3.0652463e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9996889e-01 3.1145784e-05]
# lpred [9.9982578e-01 1.7431167e-04]
# (480, 640, 3)
# a
# b
# rpred [9.99987364e-01 1.26212135e-05]
# lpred [9.9996424e-01 3.5765192e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9998426e-01 1.5759671e-05]
# lpred [9.9970549e-01 2.9450923e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9994051e-01 5.9448823e-05]
# lpred [9.9988508e-01 1.1494269e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9997234e-01 2.7620481e-05]
# lpred [9.9998856e-01 1.1465049e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999496e-01 5.040184e-05]
# lpred [9.999684e-01 3.164107e-05]
# (480, 640, 3)
# a
# b
# rpred [9.998541e-01 1.458922e-04]
# lpred [9.999540e-01 4.600527e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999685e-01 3.146279e-05]
# lpred [9.9998033e-01 1.9659779e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9994421e-01 5.5749188e-05]
# lpred [9.9994826e-01 5.1780786e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997568e-01 2.4268698e-05]
# lpred [9.99987602e-01 1.23651835e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9950767e-01 4.9234851e-04]
# lpred [9.999374e-01 6.262313e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9995303e-01 4.6917517e-05]
# lpred [9.9990606e-01 9.3911505e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9998772e-01 1.2223085e-05]
# lpred [9.9996471e-01 3.5327164e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9993253e-01 6.7509536e-05]
# lpred [9.9994707e-01 5.2916035e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9991095e-01 8.9076006e-05]
# lpred [9.9993384e-01 6.6141147e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9996245e-01 3.7567454e-05]
# lpred [9.9988902e-01 1.1101028e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9999106e-01 8.9986224e-06]
# lpred [9.9995375e-01 4.6290792e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9998593e-01 1.4007210e-05]
# lpred [9.999590e-01 4.096378e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9998283e-01 1.7140152e-05]
# lpred [9.9998486e-01 1.5177893e-05]
# (480, 640, 3)
# a
# rpred [9.9998879e-01 1.1253939e-05]
# lpred [9.9998486e-01 1.5177893e-05]
# (480, 640, 3)
# a
# b
# rpred [9.99985814e-01 1.41421315e-05]
# lpred [9.9991643e-01 8.3596824e-05]
# (480, 640, 3)
# a
# rpred [9.9998343e-01 1.6546217e-05]
# lpred [9.9991643e-01 8.3596824e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999857e-01 1.4857194e-06]
# lpred [9.99989390e-01 1.05918025e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999893e-01 1.0395654e-06]
# lpred [9.9999833e-01 1.6271217e-06]
# (480, 640, 3)
# a
# b
# rpred [9.9999714e-01 2.8706995e-06]
# lpred [9.9999237e-01 7.6165666e-06]
# (480, 640, 3)
# a
# b
# rpred [9.999958e-01 4.228282e-06]
# lpred [9.9998772e-01 1.2258304e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999838e-01 1.624189e-05]
# lpred [9.99899745e-01 1.00290505e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9998021e-01 1.9768466e-05]
# lpred [9.9997640e-01 2.3627623e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9988532e-01 1.1469033e-04]
# lpred [9.999267e-01 7.327426e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9993896e-01 6.0977498e-05]
# lpred [9.9996996e-01 3.0067376e-05]
# (480, 640, 3)
# a
# b
# rpred [9.99890089e-01 1.09955494e-04]
# lpred [9.9983835e-01 1.6161698e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9974138e-01 2.5864138e-04]
# lpred [9.9994874e-01 5.1213821e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9986696e-01 1.3299272e-04]
# lpred [9.9981302e-01 1.8698533e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9986768e-01 1.3226476e-04]
# lpred [9.9954337e-01 4.5655324e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9988747e-01 1.1253749e-04]
# lpred [9.9984264e-01 1.5736348e-04]
# (480, 640, 3)
# a
# b
# rpred [9.998258e-01 1.741990e-04]
# lpred [9.9978918e-01 2.1081208e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9990976e-01 9.0191839e-05]
# lpred [9.999790e-01 2.101051e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999769e-01 2.317543e-05]
# lpred [9.9998200e-01 1.8058432e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999857e-01 1.4722059e-06]
# lpred [9.9997652e-01 2.3431863e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9994516e-01 5.4811910e-05]
# lpred [9.999261e-01 7.392227e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999918e-01 8.271643e-06]
# lpred [9.9995422e-01 4.5817706e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999565e-01 4.349430e-05]
# lpred [9.9997044e-01 2.9545792e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997818e-01 2.1794618e-05]
# lpred [9.9996984e-01 3.0209272e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999225e-01 7.6890810e-06]
# lpred [9.999722e-01 2.781792e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9993968e-01 6.0341317e-05]
# lpred [9.9997389e-01 2.6105883e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999577e-01 4.232238e-05]
# lpred [9.9997735e-01 2.2677586e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997783e-01 2.2223028e-05]
# lpred [9.9997211e-01 2.7858458e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9999666e-01 3.3488325e-06]
# lpred [9.9989867e-01 1.0127758e-04]
# (480, 640, 3)
# a
# b
# rpred [9.999883e-01 1.167110e-05]
# lpred [9.9992406e-01 7.5974502e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9998534e-01 1.4701977e-05]
# lpred [9.9982482e-01 1.7517406e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9997866e-01 2.1383888e-05]
# lpred [9.9995065e-01 4.9350398e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997401e-01 2.5958889e-05]
# lpred [9.9997830e-01 2.1722244e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9988937e-01 1.1064462e-04]
# lpred [9.9997747e-01 2.2571130e-05]
# (480, 640, 3)
# a
# b
# rpred [9.9997759e-01 2.2458707e-05]
# lpred [9.999931e-01 6.967331e-06]
# (480, 640, 3)
# a
# b
# rpred [9.9995303e-01 4.6927449e-05]
# lpred [9.9982470e-01 1.7536426e-04]
# (480, 640, 3)
# a
# b
# rpred [9.9994373e-01 5.6231005e-05]
# lpred [9.996257e-01 3.742825e-04]
# (480, 640, 3)
# a
# b
# rpred [9.999548e-01 4.520179e-05]
# lpred [9.9998069e-01 1.9269182e-05]
# (480, 640, 3)
# a
# b
# rpred [9.999212e-01 7.881563e-05]
# lpred [9.999914e-01 8.526588e-06]
# (480, 640, 3)
# a
# b
# rpred [9.9997890e-01 2.1082926e-05]
# lpred [9.9994397e-01 5.6005494e-05]
# (480, 640, 3)
# a
# b
# rpred [0.8975713  0.10242871]
# lpred [0.9977189 0.0022811]
# (480, 640, 3)
# a
# b
# rpred [0.94725984 0.05274023]
# lpred [0.99599934 0.00400072]
# (480, 640, 3)
# a
# b
# rpred [0.9628779  0.03712205]
# lpred [0.9793505  0.02064953]
# (480, 640, 3)
# a
# b
# rpred [0.02585835 0.9741416 ]
# lpred [0.8962031  0.10379694]
# (480, 640, 3)
# a
# b
# rpred [0.75273365 0.24726637]
# lpred [0.92470354 0.07529651]
# (480, 640, 3)
# a
# b
# rpred [0.97680193 0.02319803]
# lpred [0.99854517 0.00145489]
# (480, 640, 3)
# a
# b
# rpred [9.999018e-01 9.827206e-05]
# lpred [9.9997127e-01 2.8700792e-05]
# (480, 640, 3)
# a
# b
# rpred [0.99803    0.00196995]
# lpred [0.9979964  0.00200354]
# (480, 640, 3)
# b
# rpred [0.99803    0.00196995]
# lpred [0.98890215 0.01109787]
# (480, 640, 3)
# a
# b
# rpred [0.7571957  0.24280424]
# lpred [0.29102454 0.7089755 ]
# (480, 640, 3)
# a
# b
# rpred [0.8662671  0.13373294]
# lpred [0.7023168  0.29768324]
# (480, 640, 3)
# b
# rpred [0.8662671  0.13373294]
# lpred [0.6735448  0.32645518]
# (480, 640, 3)
# a
# b
# rpred [0.91609573 0.08390422]
# lpred [0.98657984 0.01342015]
# (480, 640, 3)
# b
# rpred [0.91609573 0.08390422]
# lpred [0.72518885 0.27481118]
# (480, 640, 3)
# b
# rpred [0.91609573 0.08390422]
# lpred [0.08233573 0.9176643 ]
# (480, 640, 3)
# b
# rpred [0.91609573 0.08390422]
# lpred [0.6629885 0.3370115]
# (480, 640, 3)
# a
# b
# rpred [9.9964964e-01 3.5040721e-04]
# lpred [0.8935324  0.10646764]
# (480, 640, 3)
# a
# b
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.986912   0.01308796]
# (480, 640, 3)
# b
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# rpred [9.995005e-01 4.995353e-04]
# lpred [0.92021143 0.0797885 ]
# (480, 640, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8036/2799830954.py in <module>
#       9     faces = face.detectMultiScale(gray,minNeighbors=5,scaleFactor=1.1,minSize=(25,25))
#      10     left_eye = leye.detectMultiScale(gray)
# ---> 11     right_eye =  reye.detectMultiScale(gray)
#      12
#      13     cv2.rectangle(frame, (0,height-50) , (200,height) , (0,0,0) , thickness=cv2.FILLED )
#
# KeyboardInterrupt:

# %%
cap.release()
cv2.destroyAllWindows()
